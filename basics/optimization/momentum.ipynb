# %% [markdown]
# # Momentum

# %% [markdown]
# ### Paper to read during the weekend:
#
# * [On the importance of initializaton and momentum in deep learning](https://www.cs.toronto.edu/~fritz/absps/momentum.pdf)
#
# * Misc:
#     - [Why Momentum Really Works by Goh distill](https://distill.pub/2017/momentum/)

# %%
# %matplotlib inline
import torch
from d2l import torch as d2l

eta = 0.4
def f_2d(x1, x2):
    return 0.1 * x1 ** 2 + 2 * x2 ** 2
def gd_2d(x1, x2, s1, s2):
    return (x1 - eta * 0.2 * x1, x2 - eta * 4 * x2, 0, 0)

d2l.show_trace_2d(f_2d, d2l.train_2d(gd_2d))
# Out:
# epoch 20, x1: -0.943467, x2: -0.000073

# %%
eta = 0.6
d2l.show_trace_2d(f_2d, d2l.train_2d(gd_2d))
# Out:
# epoch 20, x1: -0.387814, x2: -1673.365109

# %% [markdown]
# ## The Momentum Method

# %%
def momentum_2d(x1, x2, v1, v2):
    v1 = beta * v1 + 0.2 * x1
    v2 = beta * v2 + 4 * x2
    return x1 - eta * v1, x2 - eta * v2, v1, v2

eta, beta = 0.6, 0.5
d2l.show_trace_2d(f_2d, d2l.train_2d(momentum_2d))
# Out:
# epoch 20, x1: 0.007188, x2: 0.002553

# %%
eta, beta = 0.6, 0.25
d2l.show_trace_2d(f_2d, d2l.train_2d(momentum_2d))
# Out:
# epoch 20, x1: -0.126340, x2: -0.186632
